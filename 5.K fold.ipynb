# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
for dirname, _, filenames in os.walk('D:\\movie-recommendation-system\\Emotion_detection\\data'):
    print(dirname)
# Out:
# D:\movie-recommendation-system\Emotion_detection\data
# D:\movie-recommendation-system\Emotion_detection\data\test
# D:\movie-recommendation-system\Emotion_detection\data\test\angry
# D:\movie-recommendation-system\Emotion_detection\data\test\disgust
# D:\movie-recommendation-system\Emotion_detection\data\test\fear
# D:\movie-recommendation-system\Emotion_detection\data\test\happy
# D:\movie-recommendation-system\Emotion_detection\data\test\neutral
# D:\movie-recommendation-system\Emotion_detection\data\test\sad
# D:\movie-recommendation-system\Emotion_detection\data\test\surprise
# D:\movie-recommendation-system\Emotion_detection\data\train
# D:\movie-recommendation-system\Emotion_detection\data\train\angry
# D:\movie-recommendation-system\Emotion_detection\data\train\disgust
# D:\movie-recommendation-system\Emotion_detection\data\train\fear
# D:\movie-recommendation-system\Emotion_detection\data\train\happy
# D:\movie-recommendation-system\Emotion_detection\data\train\neutral
# D:\movie-recommendation-system\Emotion_detection\data\train\sad
# D:\movie-recommendation-system\Emotion_detection\data\train\surprise

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.models import load_model, Sequential
from keras.layers import Dropout
from keras.regularizers import l2

# Load the saved best model
original_model = load_model('best_model.h5')

# Create a new model
new_model = Sequential()

# Loop through the layers of the original model and add them to the new model
for layer in original_model.layers:
    # Add the original layer to the new model
    new_model.add(layer)

for layer in new_model.layers:
    if hasattr(layer, 'kernel_regularizer'):
        layer.kernel_regularizer = l2(0.001)  # Apply L2 regularization

    # Add Dropout after specific layers (e.g., after 'conv' layers)
    if 'conv' in layer.name or 'dense' in layer.name:  # Modify condition as per your model structure
        new_model.add(Dropout(0.5))  # Adding Dropout with a rate of 50%

# Compile the new model (use the same settings as the original model)
new_model.compile(optimizer=original_model.optimizer, 
                  loss=original_model.loss, 
                  metrics=original_model.metrics)

# Summary of the new model with Dropout layers added
new_model.summary()

# %%
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

# Define a simple learning rate schedule function
def lr_schedule(epoch):
    initial_lr = 0.0001
    drop = 0.5
    epochs_drop = 70
    lr = initial_lr * (drop ** (epoch // epochs_drop))
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)


# Saving the best model
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1)


# Define EarlyStopping
# early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1, restore_best_weights=True)

# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Parameters
k = 10  # Number of folds
batch_size = 32
image_size = (48, 48)

# Get all file paths in the directory
base_dir = 'D:\\movie-recommendation-system\\Emotion_detection\\data\\train'
all_data_dir = os.path.join(base_dir)

# Create a list of file paths and labels
file_paths = []
labels = []

for label in os.listdir(all_data_dir):
    class_dir = os.path.join(all_data_dir, label)
    for image_file in os.listdir(class_dir):
        file_paths.append(os.path.join(class_dir, image_file))
        labels.append(label)

file_paths = np.array(file_paths)
labels = np.array(labels)

# Initialize k-fold cross-validation
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Loop over each fold
for fold, (train_idx, val_idx) in enumerate(kf.split(file_paths)):
    print(f"Training fold {fold + 1}/{k}")
    
    # Split the data into training and validation for this fold
    train_file_paths, val_file_paths = file_paths[train_idx], file_paths[val_idx]
    train_labels, val_labels = labels[train_idx], labels[val_idx]
    
    # Create ImageDataGenerator for each fold
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    
    val_datagen = ImageDataGenerator(rescale=1./255)
    
    # Create training and validation generators
    train_generator = train_datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': train_file_paths, 'class': train_labels}),
        directory=all_data_dir,
        x_col='filename',
        y_col='class',
        target_size=image_size,
        color_mode='grayscale',
        class_mode='categorical',
        batch_size=batch_size
    )
    
    validation_generator = val_datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': val_file_paths, 'class': val_labels}),
        directory=all_data_dir,
        x_col='filename',
        y_col='class',
        target_size=image_size,
        color_mode='grayscale',
        class_mode='categorical',
        batch_size=batch_size
    )

    # Define or load your model
    if fold == 0:
        # Load a pre-trained model if it's the first fold
        model = load_model('best_model_fold_0.h5')  # Ensure this model exists before running
   
    else:
        # Load the model from the previous fold
        model = load_model('best_model_fold_{}.h5'.format(fold - 1))

    # Create an optimizer with the specified learning rate
    learning_rate = 0.001  # Initial learning rate
    optimizer = Adam(learning_rate=learning_rate)

    # Compile your model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Define a checkpoint to save the best model during training
    checkpoint = ModelCheckpoint('best_model_fold_{}.h5'.format(fold), monitor='val_loss', save_best_only=True, verbose=1)
    
    # Define learning rate scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

    # Fit the model
    history = model.fit(
        train_generator,
        epochs=20,
        validation_data=validation_generator,
        steps_per_epoch=len(train_generator),
        validation_steps=len(validation_generator),
        callbacks=[checkpoint, lr_scheduler]
    )
# Out:
# Training fold 1/10
# Found 24724 validated image filenames belonging to 7 classes.
# Found 2748 validated image filenames belonging to 7 classes.
# Epoch 1/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8951 - accuracy: 0.6657
# Epoch 1: val_loss improved from inf to 0.78686, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 412s 532ms/step - loss: 0.8951 - accuracy: 0.6657 - val_loss: 0.7869 - val_accuracy: 0.7205 - lr: 0.0010
# Epoch 2/20
# d:\movie-recommendation-system\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 773/773 [==============================] - ETA: 0s - loss: 0.8785 - accuracy: 0.6733
# Epoch 2: val_loss improved from 0.78686 to 0.78046, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 394s 509ms/step - loss: 0.8785 - accuracy: 0.6733 - val_loss: 0.7805 - val_accuracy: 0.7169 - lr: 0.0010
# Epoch 3/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.6764
# Epoch 3: val_loss did not improve from 0.78046
# 773/773 [==============================] - 394s 510ms/step - loss: 0.8739 - accuracy: 0.6764 - val_loss: 0.8172 - val_accuracy: 0.7125 - lr: 0.0010
# Epoch 4/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8719 - accuracy: 0.6760
# Epoch 4: val_loss did not improve from 0.78046
# 773/773 [==============================] - 393s 509ms/step - loss: 0.8719 - accuracy: 0.6760 - val_loss: 0.8276 - val_accuracy: 0.6994 - lr: 0.0010
# Epoch 5/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8632 - accuracy: 0.6759
# Epoch 5: val_loss did not improve from 0.78046
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 773/773 [==============================] - 395s 511ms/step - loss: 0.8632 - accuracy: 0.6759 - val_loss: 0.8076 - val_accuracy: 0.7078 - lr: 0.0010
# Epoch 6/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8100 - accuracy: 0.6990
# Epoch 6: val_loss improved from 0.78046 to 0.74942, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 395s 511ms/step - loss: 0.8100 - accuracy: 0.6990 - val_loss: 0.7494 - val_accuracy: 0.7293 - lr: 5.0000e-04
# Epoch 7/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7777 - accuracy: 0.7101
# Epoch 7: val_loss did not improve from 0.74942
# 773/773 [==============================] - 395s 512ms/step - loss: 0.7777 - accuracy: 0.7101 - val_loss: 0.7669 - val_accuracy: 0.7234 - lr: 5.0000e-04
# Epoch 8/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7692 - accuracy: 0.7170
# Epoch 8: val_loss did not improve from 0.74942
# 773/773 [==============================] - 394s 509ms/step - loss: 0.7692 - accuracy: 0.7170 - val_loss: 0.7717 - val_accuracy: 0.7223 - lr: 5.0000e-04
# Epoch 9/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.7164
# Epoch 9: val_loss did not improve from 0.74942
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 773/773 [==============================] - 409s 530ms/step - loss: 0.7618 - accuracy: 0.7164 - val_loss: 0.7586 - val_accuracy: 0.7274 - lr: 5.0000e-04
# Epoch 10/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.7316
# Epoch 10: val_loss did not improve from 0.74942
# 773/773 [==============================] - 396s 512ms/step - loss: 0.7243 - accuracy: 0.7316 - val_loss: 0.7500 - val_accuracy: 0.7260 - lr: 2.5000e-04
# Epoch 11/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7154 - accuracy: 0.7362
# Epoch 11: val_loss improved from 0.74942 to 0.74697, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 393s 508ms/step - loss: 0.7154 - accuracy: 0.7362 - val_loss: 0.7470 - val_accuracy: 0.7340 - lr: 2.5000e-04
# Epoch 12/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.7390
# Epoch 12: val_loss improved from 0.74697 to 0.73798, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 395s 510ms/step - loss: 0.6989 - accuracy: 0.7390 - val_loss: 0.7380 - val_accuracy: 0.7369 - lr: 2.5000e-04
# Epoch 13/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7392
# Epoch 13: val_loss did not improve from 0.73798
# 773/773 [==============================] - 394s 510ms/step - loss: 0.7014 - accuracy: 0.7392 - val_loss: 0.7435 - val_accuracy: 0.7325 - lr: 2.5000e-04
# Epoch 14/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.7414
# Epoch 14: val_loss did not improve from 0.73798
# 773/773 [==============================] - 394s 509ms/step - loss: 0.6936 - accuracy: 0.7414 - val_loss: 0.7396 - val_accuracy: 0.7373 - lr: 2.5000e-04
# Epoch 15/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6979 - accuracy: 0.7426
# Epoch 15: val_loss did not improve from 0.73798
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 773/773 [==============================] - 1131s 1s/step - loss: 0.6979 - accuracy: 0.7426 - val_loss: 0.7515 - val_accuracy: 0.7300 - lr: 2.5000e-04
# Epoch 16/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6776 - accuracy: 0.7478
# Epoch 16: val_loss improved from 0.73798 to 0.73778, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 648s 839ms/step - loss: 0.6776 - accuracy: 0.7478 - val_loss: 0.7378 - val_accuracy: 0.7376 - lr: 1.2500e-04
# Epoch 17/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7529
# Epoch 17: val_loss did not improve from 0.73778
# 773/773 [==============================] - 515s 666ms/step - loss: 0.6636 - accuracy: 0.7529 - val_loss: 0.7396 - val_accuracy: 0.7365 - lr: 1.2500e-04
# Epoch 18/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6586 - accuracy: 0.7567
# Epoch 18: val_loss did not improve from 0.73778
# 773/773 [==============================] - 547s 708ms/step - loss: 0.6586 - accuracy: 0.7567 - val_loss: 0.7410 - val_accuracy: 0.7347 - lr: 1.2500e-04
# Epoch 19/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6691 - accuracy: 0.7518
# Epoch 19: val_loss did not improve from 0.73778
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 773/773 [==============================] - 484s 626ms/step - loss: 0.6691 - accuracy: 0.7518 - val_loss: 0.7438 - val_accuracy: 0.7384 - lr: 1.2500e-04
# Epoch 20/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6589 - accuracy: 0.7562
# Epoch 20: val_loss improved from 0.73778 to 0.73039, saving model to best_model_fold_0.h5
# 773/773 [==============================] - 390s 504ms/step - loss: 0.6589 - accuracy: 0.7562 - val_loss: 0.7304 - val_accuracy: 0.7387 - lr: 6.2500e-05
# Training fold 2/10
# Found 24724 validated image filenames belonging to 7 classes.
# Found 2748 validated image filenames belonging to 7 classes.
# Epoch 1/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8097 - accuracy: 0.7066
# Epoch 1: val_loss improved from inf to 0.64743, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 386s 498ms/step - loss: 0.8097 - accuracy: 0.7066 - val_loss: 0.6474 - val_accuracy: 0.7693 - lr: 0.0010
# Epoch 2/20
# d:\movie-recommendation-system\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 773/773 [==============================] - ETA: 0s - loss: 0.8249 - accuracy: 0.6963
# Epoch 2: val_loss did not improve from 0.64743
# 773/773 [==============================] - 389s 503ms/step - loss: 0.8249 - accuracy: 0.6963 - val_loss: 0.6826 - val_accuracy: 0.7464 - lr: 0.0010
# Epoch 3/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8187 - accuracy: 0.6977
# Epoch 3: val_loss did not improve from 0.64743
# 773/773 [==============================] - 386s 499ms/step - loss: 0.8187 - accuracy: 0.6977 - val_loss: 0.7155 - val_accuracy: 0.7475 - lr: 0.0010
# Epoch 4/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8175 - accuracy: 0.6972
# Epoch 4: val_loss did not improve from 0.64743
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 773/773 [==============================] - 390s 504ms/step - loss: 0.8175 - accuracy: 0.6972 - val_loss: 0.6939 - val_accuracy: 0.7489 - lr: 0.0010
# Epoch 5/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7528 - accuracy: 0.7227
# Epoch 5: val_loss did not improve from 0.64743
# 773/773 [==============================] - 395s 511ms/step - loss: 0.7528 - accuracy: 0.7227 - val_loss: 0.6621 - val_accuracy: 0.7642 - lr: 5.0000e-04
# Epoch 6/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7290
# Epoch 6: val_loss did not improve from 0.64743
# 773/773 [==============================] - 386s 499ms/step - loss: 0.7398 - accuracy: 0.7290 - val_loss: 0.6544 - val_accuracy: 0.7624 - lr: 5.0000e-04
# Epoch 7/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.7319
# Epoch 7: val_loss did not improve from 0.64743
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 773/773 [==============================] - 386s 499ms/step - loss: 0.7208 - accuracy: 0.7319 - val_loss: 0.6545 - val_accuracy: 0.7580 - lr: 5.0000e-04
# Epoch 8/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6893 - accuracy: 0.7468
# Epoch 8: val_loss improved from 0.64743 to 0.63456, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 387s 500ms/step - loss: 0.6893 - accuracy: 0.7468 - val_loss: 0.6346 - val_accuracy: 0.7689 - lr: 2.5000e-04
# Epoch 9/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6752 - accuracy: 0.7485
# Epoch 9: val_loss improved from 0.63456 to 0.63251, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 387s 501ms/step - loss: 0.6752 - accuracy: 0.7485 - val_loss: 0.6325 - val_accuracy: 0.7747 - lr: 2.5000e-04
# Epoch 10/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.7520
# Epoch 10: val_loss did not improve from 0.63251
# 773/773 [==============================] - 387s 501ms/step - loss: 0.6679 - accuracy: 0.7520 - val_loss: 0.6332 - val_accuracy: 0.7747 - lr: 2.5000e-04
# Epoch 11/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6590 - accuracy: 0.7528
# Epoch 11: val_loss improved from 0.63251 to 0.62748, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 386s 499ms/step - loss: 0.6590 - accuracy: 0.7528 - val_loss: 0.6275 - val_accuracy: 0.7762 - lr: 2.5000e-04
# Epoch 12/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6588 - accuracy: 0.7572
# Epoch 12: val_loss did not improve from 0.62748
# 773/773 [==============================] - 387s 500ms/step - loss: 0.6588 - accuracy: 0.7572 - val_loss: 0.6407 - val_accuracy: 0.7697 - lr: 2.5000e-04
# Epoch 13/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7566
# Epoch 13: val_loss did not improve from 0.62748
# 773/773 [==============================] - 389s 504ms/step - loss: 0.6565 - accuracy: 0.7566 - val_loss: 0.6439 - val_accuracy: 0.7678 - lr: 2.5000e-04
# Epoch 14/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6485 - accuracy: 0.7565
# Epoch 14: val_loss did not improve from 0.62748
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 773/773 [==============================] - 396s 512ms/step - loss: 0.6485 - accuracy: 0.7565 - val_loss: 0.6313 - val_accuracy: 0.7718 - lr: 2.5000e-04
# Epoch 15/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6374 - accuracy: 0.7633
# Epoch 15: val_loss did not improve from 0.62748
# 773/773 [==============================] - 387s 501ms/step - loss: 0.6374 - accuracy: 0.7633 - val_loss: 0.6314 - val_accuracy: 0.7744 - lr: 1.2500e-04
# Epoch 16/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6230 - accuracy: 0.7718
# Epoch 16: val_loss improved from 0.62748 to 0.62591, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 388s 502ms/step - loss: 0.6230 - accuracy: 0.7718 - val_loss: 0.6259 - val_accuracy: 0.7718 - lr: 1.2500e-04
# Epoch 17/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.7712
# Epoch 17: val_loss improved from 0.62591 to 0.62422, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 391s 505ms/step - loss: 0.6262 - accuracy: 0.7712 - val_loss: 0.6242 - val_accuracy: 0.7751 - lr: 1.2500e-04
# Epoch 18/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.7729
# Epoch 18: val_loss did not improve from 0.62422
# 773/773 [==============================] - 602s 779ms/step - loss: 0.6200 - accuracy: 0.7729 - val_loss: 0.6265 - val_accuracy: 0.7711 - lr: 1.2500e-04
# Epoch 19/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.7741
# Epoch 19: val_loss improved from 0.62422 to 0.61982, saving model to best_model_fold_1.h5
# 773/773 [==============================] - 608s 787ms/step - loss: 0.6090 - accuracy: 0.7741 - val_loss: 0.6198 - val_accuracy: 0.7762 - lr: 1.2500e-04
# Epoch 20/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6143 - accuracy: 0.7737
# Epoch 20: val_loss did not improve from 0.61982
# 773/773 [==============================] - 642s 831ms/step - loss: 0.6143 - accuracy: 0.7737 - val_loss: 0.6299 - val_accuracy: 0.7678 - lr: 1.2500e-04
# Training fold 3/10
# Found 24725 validated image filenames belonging to 7 classes.
# Found 2747 validated image filenames belonging to 7 classes.
# Epoch 1/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7816 - accuracy: 0.7113
# Epoch 1: val_loss improved from inf to 0.49484, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 481s 620ms/step - loss: 0.7816 - accuracy: 0.7113 - val_loss: 0.4948 - val_accuracy: 0.8380 - lr: 0.0010
# Epoch 2/20
# d:\movie-recommendation-system\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 773/773 [==============================] - ETA: 0s - loss: 0.8112 - accuracy: 0.7025
# Epoch 2: val_loss did not improve from 0.49484
# 773/773 [==============================] - 399s 516ms/step - loss: 0.8112 - accuracy: 0.7025 - val_loss: 0.5472 - val_accuracy: 0.8202 - lr: 0.0010
# Epoch 3/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8076 - accuracy: 0.6981
# Epoch 3: val_loss did not improve from 0.49484
# 773/773 [==============================] - 386s 499ms/step - loss: 0.8076 - accuracy: 0.6981 - val_loss: 0.5636 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 4/20
# 773/773 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.7028
# Epoch 4: val_loss did not improve from 0.49484
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 773/773 [==============================] - 385s 498ms/step - loss: 0.8058 - accuracy: 0.7028 - val_loss: 0.6624 - val_accuracy: 0.7627 - lr: 0.0010
# Epoch 5/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7437 - accuracy: 0.7213
# Epoch 5: val_loss did not improve from 0.49484
# 773/773 [==============================] - 384s 497ms/step - loss: 0.7437 - accuracy: 0.7213 - val_loss: 0.4964 - val_accuracy: 0.8413 - lr: 5.0000e-04
# Epoch 6/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.7341
# Epoch 6: val_loss did not improve from 0.49484
# 773/773 [==============================] - 387s 500ms/step - loss: 0.7169 - accuracy: 0.7341 - val_loss: 0.5044 - val_accuracy: 0.8358 - lr: 5.0000e-04
# Epoch 7/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7111 - accuracy: 0.7380
# Epoch 7: val_loss did not improve from 0.49484
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 773/773 [==============================] - 385s 498ms/step - loss: 0.7111 - accuracy: 0.7380 - val_loss: 0.5055 - val_accuracy: 0.8384 - lr: 5.0000e-04
# Epoch 8/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6767 - accuracy: 0.7498
# Epoch 8: val_loss improved from 0.49484 to 0.46477, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 389s 503ms/step - loss: 0.6767 - accuracy: 0.7498 - val_loss: 0.4648 - val_accuracy: 0.8500 - lr: 2.5000e-04
# Epoch 9/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.7523
# Epoch 9: val_loss improved from 0.46477 to 0.44012, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 384s 497ms/step - loss: 0.6679 - accuracy: 0.7523 - val_loss: 0.4401 - val_accuracy: 0.8551 - lr: 2.5000e-04
# Epoch 10/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7572
# Epoch 10: val_loss did not improve from 0.44012
# 773/773 [==============================] - 394s 510ms/step - loss: 0.6553 - accuracy: 0.7572 - val_loss: 0.4580 - val_accuracy: 0.8526 - lr: 2.5000e-04
# Epoch 11/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6601 - accuracy: 0.7523
# Epoch 11: val_loss did not improve from 0.44012
# 773/773 [==============================] - 389s 504ms/step - loss: 0.6601 - accuracy: 0.7523 - val_loss: 0.4542 - val_accuracy: 0.8573 - lr: 2.5000e-04
# Epoch 12/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.7643
# Epoch 12: val_loss did not improve from 0.44012
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 773/773 [==============================] - 390s 505ms/step - loss: 0.6460 - accuracy: 0.7643 - val_loss: 0.4631 - val_accuracy: 0.8489 - lr: 2.5000e-04
# Epoch 13/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.7655
# Epoch 13: val_loss did not improve from 0.44012
# 773/773 [==============================] - 393s 508ms/step - loss: 0.6307 - accuracy: 0.7655 - val_loss: 0.4440 - val_accuracy: 0.8526 - lr: 1.2500e-04
# Epoch 14/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7681
# Epoch 14: val_loss improved from 0.44012 to 0.43904, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 395s 511ms/step - loss: 0.6295 - accuracy: 0.7681 - val_loss: 0.4390 - val_accuracy: 0.8537 - lr: 1.2500e-04
# Epoch 15/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6186 - accuracy: 0.7704
# Epoch 15: val_loss did not improve from 0.43904
# 773/773 [==============================] - 397s 513ms/step - loss: 0.6186 - accuracy: 0.7704 - val_loss: 0.4417 - val_accuracy: 0.8500 - lr: 1.2500e-04
# Epoch 16/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6167 - accuracy: 0.7699
# Epoch 16: val_loss did not improve from 0.43904
# 773/773 [==============================] - 395s 510ms/step - loss: 0.6167 - accuracy: 0.7699 - val_loss: 0.4427 - val_accuracy: 0.8558 - lr: 1.2500e-04
# Epoch 17/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.7702
# Epoch 17: val_loss did not improve from 0.43904
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 773/773 [==============================] - 394s 509ms/step - loss: 0.6136 - accuracy: 0.7702 - val_loss: 0.4399 - val_accuracy: 0.8566 - lr: 1.2500e-04
# Epoch 18/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6059 - accuracy: 0.7712
# Epoch 18: val_loss improved from 0.43904 to 0.43569, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 394s 510ms/step - loss: 0.6059 - accuracy: 0.7712 - val_loss: 0.4357 - val_accuracy: 0.8551 - lr: 6.2500e-05
# Epoch 19/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.7758
# Epoch 19: val_loss did not improve from 0.43569
# 773/773 [==============================] - 444s 574ms/step - loss: 0.6009 - accuracy: 0.7758 - val_loss: 0.4398 - val_accuracy: 0.8555 - lr: 6.2500e-05
# Epoch 20/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6028 - accuracy: 0.7789
# Epoch 20: val_loss improved from 0.43569 to 0.43517, saving model to best_model_fold_2.h5
# 773/773 [==============================] - 512s 663ms/step - loss: 0.6028 - accuracy: 0.7789 - val_loss: 0.4352 - val_accuracy: 0.8577 - lr: 6.2500e-05
# Training fold 4/10
# Found 24725 validated image filenames belonging to 7 classes.
# Found 2747 validated image filenames belonging to 7 classes.
# Epoch 1/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7615 - accuracy: 0.7199
# Epoch 1: val_loss improved from inf to 0.48850, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 479s 618ms/step - loss: 0.7615 - accuracy: 0.7199 - val_loss: 0.4885 - val_accuracy: 0.8497 - lr: 0.0010
# Epoch 2/20
# d:\movie-recommendation-system\venv\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 773/773 [==============================] - ETA: 0s - loss: 0.7815 - accuracy: 0.7095
# Epoch 2: val_loss improved from 0.48850 to 0.47795, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 468s 606ms/step - loss: 0.7815 - accuracy: 0.7095 - val_loss: 0.4780 - val_accuracy: 0.8442 - lr: 0.0010
# Epoch 3/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7875 - accuracy: 0.7087
# Epoch 3: val_loss did not improve from 0.47795
# 773/773 [==============================] - 460s 595ms/step - loss: 0.7875 - accuracy: 0.7087 - val_loss: 0.5281 - val_accuracy: 0.8143 - lr: 0.0010
# Epoch 4/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7941 - accuracy: 0.7072
# Epoch 4: val_loss did not improve from 0.47795
# 773/773 [==============================] - 471s 609ms/step - loss: 0.7941 - accuracy: 0.7072 - val_loss: 0.5448 - val_accuracy: 0.8140 - lr: 0.0010
# Epoch 5/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7913 - accuracy: 0.7075
# Epoch 5: val_loss did not improve from 0.47795
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 773/773 [==============================] - 410s 530ms/step - loss: 0.7913 - accuracy: 0.7075 - val_loss: 0.5158 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 6/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7220 - accuracy: 0.7340
# Epoch 6: val_loss did not improve from 0.47795
# 773/773 [==============================] - 388s 502ms/step - loss: 0.7220 - accuracy: 0.7340 - val_loss: 0.4841 - val_accuracy: 0.8344 - lr: 5.0000e-04
# Epoch 7/20
# 773/773 [==============================] - ETA: 0s - loss: 0.7030 - accuracy: 0.7428
# Epoch 7: val_loss did not improve from 0.47795
# 773/773 [==============================] - 415s 537ms/step - loss: 0.7030 - accuracy: 0.7428 - val_loss: 0.4958 - val_accuracy: 0.8376 - lr: 5.0000e-04
# Epoch 8/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6840 - accuracy: 0.7464
# Epoch 8: val_loss did not improve from 0.47795
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 773/773 [==============================] - 399s 516ms/step - loss: 0.6840 - accuracy: 0.7464 - val_loss: 0.4793 - val_accuracy: 0.8384 - lr: 5.0000e-04
# Epoch 9/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.7561
# Epoch 9: val_loss improved from 0.47795 to 0.46064, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 401s 519ms/step - loss: 0.6573 - accuracy: 0.7561 - val_loss: 0.4606 - val_accuracy: 0.8420 - lr: 2.5000e-04
# Epoch 10/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6389 - accuracy: 0.7647
# Epoch 10: val_loss improved from 0.46064 to 0.44570, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 395s 510ms/step - loss: 0.6389 - accuracy: 0.7647 - val_loss: 0.4457 - val_accuracy: 0.8482 - lr: 2.5000e-04
# Epoch 11/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.7685
# Epoch 11: val_loss improved from 0.44570 to 0.43862, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 406s 525ms/step - loss: 0.6325 - accuracy: 0.7685 - val_loss: 0.4386 - val_accuracy: 0.8540 - lr: 2.5000e-04
# Epoch 12/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.7680
# Epoch 12: val_loss did not improve from 0.43862
# 773/773 [==============================] - 422s 546ms/step - loss: 0.6297 - accuracy: 0.7680 - val_loss: 0.4430 - val_accuracy: 0.8464 - lr: 2.5000e-04
# Epoch 13/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6263 - accuracy: 0.7708
# Epoch 13: val_loss did not improve from 0.43862
# 773/773 [==============================] - 460s 595ms/step - loss: 0.6263 - accuracy: 0.7708 - val_loss: 0.4430 - val_accuracy: 0.8569 - lr: 2.5000e-04
# Epoch 14/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.7729
# Epoch 14: val_loss improved from 0.43862 to 0.43853, saving model to best_model_fold_3.h5
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 773/773 [==============================] - 473s 612ms/step - loss: 0.6206 - accuracy: 0.7729 - val_loss: 0.4385 - val_accuracy: 0.8548 - lr: 2.5000e-04
# Epoch 15/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6095 - accuracy: 0.7750
# Epoch 15: val_loss improved from 0.43853 to 0.43194, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 573s 742ms/step - loss: 0.6095 - accuracy: 0.7750 - val_loss: 0.4319 - val_accuracy: 0.8555 - lr: 1.2500e-04
# Epoch 16/20
# 773/773 [==============================] - ETA: 0s - loss: 0.6014 - accuracy: 0.7783
# Epoch 16: val_loss improved from 0.43194 to 0.42695, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 531s 687ms/step - loss: 0.6014 - accuracy: 0.7783 - val_loss: 0.4269 - val_accuracy: 0.8606 - lr: 1.2500e-04
# Epoch 17/20
# 773/773 [==============================] - ETA: 0s - loss: 0.5958 - accuracy: 0.7819
# Epoch 17: val_loss did not improve from 0.42695
# 773/773 [==============================] - 439s 568ms/step - loss: 0.5958 - accuracy: 0.7819 - val_loss: 0.4290 - val_accuracy: 0.8555 - lr: 1.2500e-04
# Epoch 18/20
# 773/773 [==============================] - ETA: 0s - loss: 0.5843 - accuracy: 0.7805
# Epoch 18: val_loss improved from 0.42695 to 0.41570, saving model to best_model_fold_3.h5
# 773/773 [==============================] - 440s 569ms/step - loss: 0.5843 - accuracy: 0.7805 - val_loss: 0.4157 - val_accuracy: 0.8580 - lr: 1.2500e-04
# Epoch 19/20
# 773/773 [==============================] - ETA: 0s - loss: 0.5813 - accuracy: 0.7853
# Epoch 19: val_loss did not improve from 0.41570
# 773/773 [==============================] - 453s 587ms/step - loss: 0.5813 - accuracy: 0.7853 - val_loss: 0.4194 - val_accuracy: 0.8598 - lr: 1.2500e-04
# Epoch 20/20
# 773/773 [==============================] - ETA: 0s - loss: 0.5795 - accuracy: 0.7852
# Epoch 20: val_loss did not improve from 0.41570
# 773/773 [==============================] - 492s 637ms/step - loss: 0.5795 - accuracy: 0.7852 - val_loss: 0.4221 - val_accuracy: 0.8609 - lr: 1.2500e-04
# Training fold 5/10
# Found 24725 validated image filenames belonging to 7 classes.
# Found 2747 validated image filenames belonging to 7 classes.
# Epoch 1/20
# 162/773 [=====>........................] - ETA: 6:05 - loss: 0.7044 - accuracy: 0.7427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 99
#      96 lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
#      98 # Fit the model
# ---> 99 history = model.fit(
#     100     train_generator,
#     101     epochs=20,
#     102     validation_data=validation_generator,
#     103     steps_per_epoch=len(train_generator),
#     104     validation_steps=len(validation_generator),
#     105     callbacks=[checkpoint, lr_scheduler]
#     106 )
#
# File d:\movie-recommendation-system\venv\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\movie-recommendation-system\venv\lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File d:\movie-recommendation-system\venv\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


predictions = model.predict(training_set2)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = training_set2.classes
labels = ['angry', 'disgust', 'fear','happy', 'neutral', 'sad', 'surprise']

conf_matrix = confusion_matrix(true_labels, predicted_labels)


plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 687/687 [==============================] - 70s 102ms/step

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,   ## rescale or normalize the images pixels, by dividing them 255
    shear_range = 0.2,  ## angle for slant of image in degrees
    zoom_range = 0.2,   ## for zoom in or out
    horizontal_flip = True 
)
training_set = train_datagen.flow_from_directory(
    'D:\\movie-recommendation-system\\Emotion_detection\\data\\train',   ## give path of training set
    target_size=(48,48),      ## target_size of image in which you want
    batch_size=32,
    color_mode = "grayscale",
    class_mode = 'categorical'
)
# Out:
# Found 27472 images belonging to 7 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
    'D:\\movie-recommendation-system\\Emotion_detection\\data\\test',
    target_size = (48,48),
    batch_size = 32,
    color_mode = "grayscale",
    class_mode = 'categorical'
)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
train_loss, train_acc = model.evaluate(training_set)
test_loss, test_acc   = model.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_acc*100, test_acc*100))
# Out:
# 859/859 [==============================] - 121s 140ms/step - loss: 0.4623 - accuracy: 0.8441
# 225/225 [==============================] - 75s 334ms/step - loss: 0.8018 - accuracy: 0.7208
# final train accuracy = 84.41 , validation accuracy = 72.08
